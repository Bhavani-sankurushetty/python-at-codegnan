# %%
name = input()
print("Hello, ",name)
# Out:
#  bhavani
# Hello,  bhavani

# %%
x,y = map(int,input().split())
print(f'{x} + {y} = {x+y}')
print(f'{x} * {y} = {x*y}')
print(f'{x} - {y} = {x-y}')
# Out:
#  5 10
# 5 + 10 = 15
# 5 * 10 = 50
# 5 - 10 = -5

# %%
A, B, C, D = map(int, input().split())
X = (A * B) - (C * D)
print("Difference =", X)
# Out:
#  1 2 3 4
# Difference = -10

# %%
r = float(input())
pie =  3.141592653
res = r*r
print(res*pie)
# Out:
#  2.00
# 12.566370612

# %%
s=input().split()
l=list(s)
freq={}
for ch in l:
    if ch in freq:
        freq[ch]+=1
    else:
        freq[ch]=1
print(freq)
# Out:
#  bread butter bread
# {'bread': 2, 'butter': 1}

# %%
n, m = map(int, input().split())

print((n % 10) + (m % 10))
