# %%
arr = list(map(int, input().split()))
target = int(input())
res = []
for num in arr:
    if num != target:
        res.append(num)
print(res)
# Out:
#  1 2 3 4 3 32 35 3 3
#  3
# [1, 2, 4, 32, 35]

# %%
arr = list(map(int, input().split()))
target = int(input())
res = []
n = len(arr)
i = 0 # initilization
while i < n:
    if arr[i] != target:
        res.append(arr[i])
    i+=1print(res)
# Out:
#  3 3 3 3
#  3
# []

# %%
arr = list(map(int, input().split()))
target = int(input())
n = len(arr)
i = 0 # initilization
while i < n:
    if arr[i] == target:
        arr.pop(i)
        n-=1
    else:
        i+=1
        
print(arr)
# Out:
#  2 3 2 3 4 5 34 3
#  3
# [2, 2, 4, 5, 34]

# %%
# return the target element porition of target exists otherwise -1
arr = list(map(int, input(). split()))
target = int(input())
res = -1
n = len(arr)
for i in range(n):
    if arr[i] == target:
        res = i
print(res)
# Out:
#  1 2 3 4 5 6 7
#  3
# 2

# %%
arr = list(map(int, input(). split()))
target = int(input())
n = len(arr)
for i in range(n):
    if arr[i] == target:
        res = i
        print(i)
        break
else:
    print(-1)
# Out:
#  1 2 3 4 5 6
#  3
# 2

# %%
arr = [1,2,3,2,3,4]
target = 3
n = len(arr)
i = 0 # initilization
while i < n:
    if arr[i] == target:
        arr.pop(i)
        n-=1
        continue
    i+= 1
print(arr)
# Out:
# [1, 2, 2, 4]
