# %%
#
name  = "bhavani"
age = 20
marks = [86,98,76,68,45]
print(" My name " + name + " and i am a " + str(age) + " years old ")
# Out:
#  My name bhavani and i am a 20 years old

# %%
## output fromatting
# 1. old style formatting ( using comma)
name  = "bhavani"
age = 20
marks = [86,98,76,68,45]
print(" My name " , name , " and i am a " , age , " years old ")
# Out:
#  My name  bhavani  and i am a  20  years old

# %%
# 1 . access specifiers
# integer - %d
# float - %f
# string - %s
name  = "bhavani"
age = 20
marks = [86,98,76,68,45]
print(" My name %s and i am a %d years old "%(name,age))
# Out:
#  My name bhavani and i am a 20 years old

# %%
## output formatting
# 3. dor format
name  = "bhavani"
age = 20
marks = [86,98,76,68,45]
print(" My name {} and i am a {} years old ".format(name,age))
print(" My name {} and i am a {} years old ".format(age,name))
# Out:
#  My name bhavani and i am a 20 years old
#  My name 20 and i am a bhavani years old

# %%
# 4. f format
name  = "bhavani"
age = 20
marks = [86,98,76,68,45]
percentage = 98.2568
print(f" My name {name} and i am a {age} years old and my percentage is {percentage}")
print(f" My name {name} and i am a {age} years old and my percentage is {percentage:.2f}")
# Out:
#  My name bhavani and i am a 20 years old and my percentage is 98.2568
#  My name bhavani and i am a 20 years old and my percentage is 98.26

# %%
num = int(input())
if num>=0:
    print(f"{num} is +ve")
else:
    print(f"{num} id -ve")
# Out:
#  8
# 8 is +ve

# %%
# check whether the given number is divisible by 5 and 3
num = int(input())
if num%3==0 and num%5==0:
    print(f"{num} is divisible by 5 and 3")
else:
    print(f"{num} is divisible by 5 and 3")
# Out:
#  15
# 15 is divisible by 5 and 3

# %%
# check whether the number is perfect square or not
num = int(input())
val = num ** 0.5
print(val)
if val == int(val):
    print(f"{num} is perfect square")
else:
    print(f"{num} is not perfect square")
# Out:
#  16
# 4.0
# 16 is perfect square
